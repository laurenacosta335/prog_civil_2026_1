# %% [markdown]
# <a href="https://colab.research.google.com/github/laurenacosta335/prog_civil_2026_1/blob/main/Primer_Notebooks_Nota_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # UNIVERSIDAD DE SUCRE
# **facultad de ingenieria**
# **departamento de ingenieria civil**
# **Lauren Sofia Benitez Acosta:1101126596**
#
# **aspectos  basicos de la  programacion con python** Empecemos con un **problema sencillo de ingeniería** usando **variables y operadores en Python**. Trabajaremos paso a paso como se hace en ingeniería: **análisis → algoritmo → pseudocódigo → código Python**.
#
# ---
#
# # Problema de Ingeniería (Ejemplo básico)
#
# Un ingeniero agrícola necesita calcular **el área de un terreno rectangular** para estimar la cantidad de fertilizante que debe aplicar.
#
# La fórmula es:
#
# [
# Área = largo \times ancho
# ]
#
# ---
#
# # 1. Definición del algoritmo (Entradas – Proceso – Salidas)
#
# ### Entradas
#
# Datos que el usuario debe proporcionar.
#
# * `largo` del terreno (m)
# * `ancho` del terreno (m)
#
# ### Proceso
#
# Operación matemática para obtener el resultado.
#
# * Calcular
#   `area = largo * ancho`
#
# ### Salida
#
# Resultado que el programa mostrará.
#
# * Área del terreno en **metros cuadrados (m²)**
#
# ---
#
# # 2. Diseño del algoritmo (explicación lógica)
#
# 1. Solicitar al usuario el **largo del terreno**
# 2. Solicitar el **ancho del terreno**
# 3. Multiplicar largo por ancho
# 4. Mostrar el área calculada
#
# ---
#
# # 3. Pseudocódigo
#
# ```text
# INICIO
#
# leer largo
# leer ancho
#
# area ← largo * ancho
#
# mostrar "El área del terreno es:", area
#
# FIN
# ```
#
# ---
#
# # 4. Implementación en Python
#
# ```python
# # Programa para calcular el área de un terreno rectangular
# # Autor: Estudiante de Ingeniería
#
# # Entrada de datos
# largo = float(input("Ingrese el largo del terreno (m): "))
# ancho = float(input("Ingrese el ancho del terreno (m): "))
#
# # Proceso
# area = largo * ancho
#
# # Salida
# print("El área del terreno es:", area, "m²")
# ```
#
# ---
#
# # 5. Ejemplo de ejecución
#
# Entrada del usuario:
#
# ```
# Largo = 20
# Ancho = 10
# ```
#
# Resultado:
#
# ```
# El área del terreno es: 200 m²
# ```
#
# ---
#
# 💡 **Conceptos de Python utilizados**
#
# * **Variables:** `largo`, `ancho`, `area`
# * **Operador matemático:** `*` (multiplicación)
# * **Entrada de datos:** `input()`
# * **Salida:** `print()`
# * **Conversión numérica:** `float()`
#
# ---
#
# ✅ **Ejercicio para ti**
#
# Antes de seguir, intenta responder:
#
# **Si un terreno tiene:**
#
# * largo = 35 m
# * ancho = 12 m
#
# ¿Cuál sería el área?
#
# Luego podemos avanzar al **Nivel 2**, donde veremos:
#
# * operadores más complejos
# * **condicionales (`if`)**
# * un problema real de **ingeniería civil o agrícola**.
